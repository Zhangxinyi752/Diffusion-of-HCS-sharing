# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import csv
import matplotlib.cm as cm
import matplotlib.colors as mcolors
from matplotlib.colors import ListedColormap
from matplotlib.colors import LinearSegmentedColormap
from matplotlib.cm import ScalarMappable
import copy
from PIL import Image

# %%
#df5=df5.drop(df5.columns[4001:],axis=1)

# %%
#df3T.loc[0,'Change']=0.05*200

# %%
with Image.open('ties=6.png') as tie6:
    tie6.show()
with Image.open('ties=10.png') as tie10:
    tie10.show()
with Image.open('ties=16.png') as tie16:
    tie16.show()
with Image.open('rewire 30%.png') as rewire30:
    rewire30.show()
with Image.open('rewire 70%.png') as rewire70:
    rewire70.show()
with Image.open('rewire 100%.png') as rewire100:
    rewire100.show()

# %%
fig,ax = plt.subplots(2,3,figsize=(12,8), dpi=350)

ax[0,0].imshow(tie6)
ax[0,0].axis('off')
ax[0,0].set_title('Ties=6, Rewire 50%\nAverage path length=3.28', color='navy',fontsize=8)

ax[0,1].imshow(tie10)
ax[0,1].axis('off')
ax[0,1].set_title('Ties=10, Rewire 50%\nAverage path length=2.59', color='navy',fontsize=8)

ax[0,2].imshow(tie16)
ax[0,2].axis('off')
ax[0,2].set_title('Ties=16, Rewire 50%\nAverage path length=2.22', color='navy',fontsize=8)

ax[1,0].imshow(rewire30)
ax[1,0].axis('off')
ax[1,0].set_title('Ties=6, Rewire 30%\nAverage path length=3.52', color='navy',fontsize=8)

ax[1,1].imshow(rewire70)
ax[1,1].axis('off')
ax[1,1].set_title('Ties=6, Rewire 70%\nAverage path length=3.16', color='navy',fontsize=8)

ax[1,2].imshow(rewire100)
ax[1,2].axis('off')
ax[1,2].set_title('Ties=6, Rewire 100%\nAverage path length=3.13', color='navy',fontsize=8)

plt.savefig('Network attributes.jpg')
plt.show()

# %%
#index_to_drop = [9,11,13,15,17]
#Diffusion_attributes=Diffusion_attributes.drop(index_to_drop)
#Diffusion_attributes

# %%
#Diffusion_attributes.to_excel('Diffusion_attributes.xlsx',index=False)
